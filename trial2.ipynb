# %%
import pandas as pd
import numpy as np
a= pd.read_csv('Crop_recommendation.csv')
dic = {}
for b in a['label']:
        i= a[a['label']==b]
        Nmin = i['N'].min()
        Nmax = i['N'].max()
        Pmin = i['P'].min()
        Pmax = i['P'].max()
        Kmin = i['K'].min()
        Kmax = i['K'].max()
        phmin= i['ph'].min()
        phmax= i['ph'].max()
        humidityMin=i['humidity'].min()
        humidityMax = i['humidity'].max()
        temperatureMin=i['temperature'].min()  
        temperatureMax = i['temperature'].max()
    # Check if the crop is rice
        
        # If it is rice, add the data to the dictionary
        dic[b] = {
                'N': {'min':Nmin,'max':Nmax}, 
                'P': {'min':Pmin,'max':Pmax}, 
                'K': {'min':Kmin,'max':Kmax},
            'ph': {'min':phmin,'max':phmax}, 
            'humidity': {'min':humidityMin,'max':humidityMax}, 
            'temperature': {'min':temperatureMin,'max':temperatureMax}
        }

# %%
dic
# Out:
# {'rice': {'N': {'min': 60, 'max': 99},
#   'P': {'min': 35, 'max': 60},
#   'K': {'min': 35, 'max': 45},
#   'ph': {'min': 5.005306977, 'max': 7.868474653},
#   'humidity': {'min': 80.12267476, 'max': 84.96907151},
#   'temperature': {'min': 20.0454142, 'max': 26.92995077}},
#  'maize': {'N': {'min': 60, 'max': 100},
#   'P': {'min': 35, 'max': 60},
#   'K': {'min': 15, 'max': 25},
#   'ph': {'min': 5.513697923, 'max': 6.995843776},
#   'humidity': {'min': 55.28220433, 'max': 74.82913698},
#   'temperature': {'min': 18.04185513, 'max': 26.54986394}},
#  'chickpea': {'N': {'min': 20, 'max': 60},
#   'P': {'min': 55, 'max': 80},
#   'K': {'min': 75, 'max': 85},
#   'ph': {'min': 5.988992796000002, 'max': 8.868741443},
#   'humidity': {'min': 14.25803981, 'max': 19.96978871},
#   'temperature': {'min': 17.02498456, 'max': 20.99502153}},
#  'kidneybeans': {'N': {'min': 0, 'max': 40},
#   'P': {'min': 55, 'max': 80},
#   'K': {'min': 15, 'max': 25},
#   'ph': {'min': 5.502999119, 'max': 5.99812453},
#   'humidity': {'min': 18.09224048, 'max': 24.96969858},
#   'temperature': {'min': 15.33042636, 'max': 24.92360104}},
#  'pigeonpeas': {'N': {'min': 0, 'max': 40},
#   'P': {'min': 55, 'max': 80},
#   'K': {'min': 15, 'max': 25},
#   'ph': {'min': 4.548202098, 'max': 7.445444882999999},
#   'humidity': {'min': 30.40046769, 'max': 69.69141302},
#   'temperature': {'min': 18.31910448, 'max': 36.97794384}},
#  'mothbeans': {'N': {'min': 0, 'max': 40},
#   'P': {'min': 35, 'max': 60},
#   'K': {'min': 15, 'max': 25},
#   'ph': {'min': 3.504752314, 'max': 9.93509073},
#   'humidity': {'min': 40.00933429, 'max': 64.95585424},
#   'temperature': {'min': 24.01825377, 'max': 31.99928579}},
#  'mungbean': {'N': {'min': 0, 'max': 40},
#   'P': {'min': 35, 'max': 60},
#   'K': {'min': 15, 'max': 25},
#   'ph': {'min': 6.218923893, 'max': 7.199495367999999},
#   'humidity': {'min': 80.03499648, 'max': 89.99615558},
#   'temperature': {'min': 27.01470397, 'max': 29.914544300000006}},
#  'blackgram': {'N': {'min': 20, 'max': 60},
#   'P': {'min': 55, 'max': 80},
#   'K': {'min': 15, 'max': 25},
#   'ph': {'min': 6.500144962, 'max': 7.775306272000001},
#   'humidity': {'min': 60.06534859, 'max': 69.96100028},
#   'temperature': {'min': 25.09737391, 'max': 34.9466155}},
#  'lentil': {'N': {'min': 0, 'max': 40},
#   'P': {'min': 55, 'max': 80},
#   'K': {'min': 15, 'max': 25},
#   'ph': {'min': 5.91645379, 'max': 7.841496029},
#   'humidity': {'min': 60.09116626, 'max': 69.92375891},
#   'temperature': {'min': 18.06486101, 'max': 29.94413861}},
#  'pomegranate': {'N': {'min': 0, 'max': 40},
#   'P': {'min': 5, 'max': 30},
#   'K': {'min': 35, 'max': 45},
#   'ph': {'min': 5.561851831, 'max': 7.199504273},
#   'humidity': {'min': 85.12912161, 'max': 94.99897537},
#   'temperature': {'min': 18.07132963, 'max': 24.96273236}},
#  'banana': {'N': {'min': 80, 'max': 120},
#   'P': {'min': 70, 'max': 95},
#   'K': {'min': 45, 'max': 55},
#   'ph': {'min': 5.505393832999999, 'max': 6.490074429},
#   'humidity': {'min': 75.03193255, 'max': 84.97849241},
#   'temperature': {'min': 25.01018457, 'max': 29.90888522}},
#  'mango': {'N': {'min': 0, 'max': 40},
#   'P': {'min': 15, 'max': 40},
#   'K': {'min': 25, 'max': 35},
#   'ph': {'min': 4.507523551, 'max': 6.9674177660000005},
#   'humidity': {'min': 45.02236377, 'max': 54.9640534},
#   'temperature': {'min': 27.00315545, 'max': 35.99009679}},
#  'grapes': {'N': {'min': 0, 'max': 40},
#   'P': {'min': 120, 'max': 145},
#   'K': {'min': 195, 'max': 205},
#   'ph': {'min': 5.510924848999999, 'max': 6.499604931},
#   'humidity': {'min': 80.01639435, 'max': 83.98351748},
#   'temperature': {'min': 8.825674745, 'max': 41.94865736}},
#  'watermelon': {'N': {'min': 80, 'max': 120},
#   'P': {'min': 5, 'max': 30},
#   'K': {'min': 45, 'max': 55},
#   'ph': {'min': 6.000975617000001, 'max': 6.956508826},
#   'humidity': {'min': 80.02621335, 'max': 89.98405233},
#   'temperature': {'min': 24.04355803, 'max': 26.98603693}},
#  'muskmelon': {'N': {'min': 80, 'max': 120},
#   'P': {'min': 5, 'max': 30},
#   'K': {'min': 45, 'max': 55},
#   'ph': {'min': 6.002927293, 'max': 6.781050372999999},
#   'humidity': {'min': 90.01506395, 'max': 94.96218673},
#   'temperature': {'min': 27.02415146, 'max': 29.94349168}},
#  'apple': {'N': {'min': 0, 'max': 40},
#   'P': {'min': 120, 'max': 145},
#   'K': {'min': 195, 'max': 205},
#   'ph': {'min': 5.514253142, 'max': 6.4992268210000015},
#   'humidity': {'min': 90.02575116, 'max': 94.92048112},
#   'temperature': {'min': 21.0365275, 'max': 23.99686172}},
#  'orange': {'N': {'min': 0, 'max': 40},
#   'P': {'min': 5, 'max': 30},
#   'K': {'min': 5, 'max': 15},
#   'ph': {'min': 6.010391864, 'max': 7.995848977},
#   'humidity': {'min': 90.00621688, 'max': 94.96419851},
#   'temperature': {'min': 10.01081312, 'max': 34.90665289}},
#  'papaya': {'N': {'min': 31, 'max': 70},
#   'P': {'min': 46, 'max': 70},
#   'K': {'min': 45, 'max': 55},
#   'ph': {'min': 6.501521192, 'max': 6.993473247000001},
#   'humidity': {'min': 90.03863107, 'max': 94.94482086},
#   'temperature': {'min': 23.012401800000006, 'max': 43.67549305}},
#  'coconut': {'N': {'min': 0, 'max': 40},
#   'P': {'min': 5, 'max': 30},
#   'K': {'min': 25, 'max': 35},
#   'ph': {'min': 5.50158009, 'max': 6.470465614},
#   'humidity': {'min': 90.01734526, 'max': 99.98187601},
#   'temperature': {'min': 25.00872392, 'max': 29.8690834}},
#  'cotton': {'N': {'min': 100, 'max': 140},
#   'P': {'min': 35, 'max': 60},
#   'K': {'min': 15, 'max': 25},
#   'ph': {'min': 5.801047545, 'max': 7.994679507000001},
#   'humidity': {'min': 75.00539324, 'max': 84.87668973},
#   'temperature': {'min': 22.00085141, 'max': 25.99237426}},
#  'jute': {'N': {'min': 60, 'max': 100},
#   'P': {'min': 35, 'max': 60},
#   'K': {'min': 35, 'max': 45},
#   'ph': {'min': 6.002524871, 'max': 7.4880144039999985},
#   'humidity': {'min': 70.88259632, 'max': 89.89106506},
#   'temperature': {'min': 23.09433785, 'max': 26.98582182}},
#  'coffee': {'N': {'min': 80, 'max': 120},
#   'P': {'min': 15, 'max': 40},
#   'K': {'min': 25, 'max': 35},
#   'ph': {'min': 6.020947179, 'max': 7.493191968},
#   'humidity': {'min': 50.04557009, 'max': 69.94807345},
#   'temperature': {'min': 23.05951896, 'max': 27.92374437}}}

# %%
for i in dic:
    a =dic[i]
    print(a['N']['max'])

# %%
for i in dic:
    print(i)

# %%
c = pd.read_csv('Fertilizer Prediction.csv')
c

# %%
df = c
df = df.drop('Humidity ', axis=1)
df = df.drop('Moisture', axis=1)
# df = c.drop('Soil Type', axis=1)

# write the updated DataFrame back to the CSV file
# df.to_csv('Fertilizer Prediction.csv', index=False))
print(df)

# %%
import seaborn as sns

sns.displot(a[''],height=9)

# %%
import plotly.express as plt  
import matplotlib.pyplot as plt  
# %matplotlib inline
plt.rcParams["figure.figsize"] = [16,9]
a.plot(x='Hours', y='Scores', style='o', color='blue', markersize=10)
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.grid()
plt.show()

# %%
pip install plotly

# %%
a= pd.read_csv('Crop_recommendation.csv')
# sns.histplot(a['N'], bins=10)
a['N'].max()

# %%
import pickle

# Load the contents of the .pkl file
with open('RandomForest_1.pkl', 'rb') as f:
    my_object = pickle.load(f)

# Now you can use the loaded object in your code
print(my_object)

# %%
pip install sklearn

# %%
import seaborn as sb
import pandas as pd

a = pd.read_csv('Crop_recommendation.csv')
sb.set(rc={'figure.figsize':(10,8)}) # set the figure size

sb.relplot(x=a.N, y=a.P, data=a, style='label', hue=a.temperature, height=8, aspect=1.5)

# %%
import plotly.express as px
import pandas as pd

# Load data from CSV file
df = pd.read_csv('Crop_recommendation.csv')

# Create scatter plot with colored markers based on temperature
fig = px.scatter(df, x='N', y='P', color='temperature', symbol='label')

# Update layout settings
fig.update_layout(
    title='Crop Recommendation',
    xaxis_title='N',
    yaxis_title='P',
    font=dict(
        family='Arial',
        size=18,
        color='black'
    ),
    legend=dict(
        title='Temperature',
        font=dict(
            family='Arial',
            size=14,
            color='black'
        )
    )
)

# Show plot
fig.show()

# %%
dic

# %%
for i in dic:
    print(i)

# %%
df = c
df = df.drop('Humidity ', axis=1)
df = df.drop('Moisture', axis=1)
# df = c.drop('Soil Type', axis=1)

# write the updated DataFrame back to the CSV file
# df.to_csv('Fertilizer Prediction.csv', index=False))
print(df)

# %%
import plotly.express as plt  
import matplotlib.pyplot as plt  
# %matplotlib inline
plt.rcParams["figure.figsize"] = [16,9]
a.plot(x='Hours', y='Scores', style='o', color='blue', markersize=10)
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.grid()
plt.show()

# %%
a= pd.read_csv('Crop_recommendation.csv')
# sns.histplot(a['N'], bins=10)
a['N'].max()

# %%
pip install sklearn

# %%
import plotly.express as px
import pandas as pd

# Load data from CSV file
df = pd.read_csv('Crop_recommendation.csv')

# Create scatter plot with colored markers based on temperature
fig = px.scatter(df, x='N', y='P', color='temperature', symbol='label')

# Update layout settings
fig.update_layout(
    title='Crop Recommendation',
    xaxis_title='N',
    yaxis_title='P',
    font=dict(
        family='Arial',
        size=18,
        color='black'
    ),
    legend=dict(
        title='Temperature',
        font=dict(
            family='Arial',
            size=14,
            color='black'
        )
    )
)

# Show plot
fig.show()

# %%
import folium
District_center = [20.5937, 78.9629]
m = folium.Map(location=District_center, zoom_start=5)

fg = folium.FeatureGroup(name='f_data')
    # for _, row in f_data.iterrows():
popup_html = f'<table><tr><th>Crop_Name:</th><td>maize</td></tr><tr><th>Acre:</th><td>5 acre</td></tr><tr><th>Lund_size:</th><td>6 acre</td></tr></table>'
fg.add_child(folium.Marker(location=[20.5937, 78.9629], popup=popup_html, icon=folium.Icon(color='darkgreen')))
m.add_child(fg)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_050b5a39688f28dbecd90128f175efcd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_050b5a39688f28dbecd90128f175efcd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_050b5a39688f28dbecd90128f175efcd = L.map(
#                 &quot;map_050b5a39688f28dbecd90128f175efcd&quot;,
#                 {
#                     center: [20.5937, 78.9629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1539d1b753910e3f487f7ebb08420373 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_050b5a39688f28dbecd90128f175efcd);
#
#
#             var feature_group_9bf33eef5f3f1449bca847b856a0093c = L.featureGroup(
#                 {}
#             ).addTo(map_050b5a39688f28dbecd90128f175efcd);
#
#
#             var marker_3b51c9147d3edd62ec8137456f41665e = L.marker(
#                 [20.5937, 78.9629],
#                 {}
#             ).addTo(feature_group_9bf33eef5f3f1449bca847b856a0093c);
#
#
#             var icon_f7aa71c2c1e2a04b5ed2e62ebb3d22fe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkgreen&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3b51c9147d3edd62ec8137456f41665e.setIcon(icon_f7aa71c2c1e2a04b5ed2e62ebb3d22fe);
#
#
#         var popup_d6e96489574b21ee39963d85d078e211 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_14f9ec264eb7a1688c7972b341a0d241 = $(`&lt;div id=&quot;html_14f9ec264eb7a1688c7972b341a0d241&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table&gt;&lt;tr&gt;&lt;th&gt;Crop_Name:&lt;/th&gt;&lt;td&gt;maize&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th&gt;Acre:&lt;/th&gt;&lt;td&gt;5 acre&lt;/td&gt;&lt;/tr&gt;&lt;tr&gt;&lt;th&gt;Lund_size:&lt;/th&gt;&lt;td&gt;6 acre&lt;/td&gt;&lt;/tr&gt;&lt;/table&gt;&lt;/div&gt;`)[0];
#                 popup_d6e96489574b21ee39963d85d078e211.setContent(html_14f9ec264eb7a1688c7972b341a0d241);
#
#
#
#         marker_3b51c9147d3edd62ec8137456f41665e.bindPopup(popup_d6e96489574b21ee39963d85d078e211)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
